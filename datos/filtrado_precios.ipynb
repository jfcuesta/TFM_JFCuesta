# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
industries = pd.read_csv('./datos/industries.csv', sep=';', dtype='str')
companies = pd.read_csv('./datos/us-companies.csv', sep=';', dtype='str')
precios = pd.read_csv('us-shareprices-daily.csv', sep=';')

# %%
energy_list = industries[industries.Sector=='Energy'].IndustryId.unique()

# %%
energy_companies = companies[companies.IndustryId.isin(energy_list)]

# %%
energy_companies
# Out:
#      Ticker SimFinId                   Company Name IndustryId
# 16      NGL    36205         NGL Energy Partners LP     107001
# 120     APC    67564        ANADARKO PETROLEUM CORP     107002
# 137     BHI    71832               BAKER HUGHES INC     107004
# 186     KMI    88392            KINDER MORGAN, INC.     107003
# 279     DRQ   113753                  DRIL-QUIP INC     107004
# ...     ...      ...                            ...        ...
# 2028    INT   344219       WORLD FUEL SERVICES CORP     107001
# 2053    TDW   419436                  TIDEWATER INC     107004
# 2075    MDR   638112    MCDERMOTT INTERNATIONAL INC     107004
# 2096    FTI   637893                 TechnipFMC plc     107004
# 2105   TUSK   825691  MAMMOTH ENERGY SERVICES, INC.     107005
#
# [111 rows x 4 columns]

# %%
energy_prices = precios[precios.Ticker.isin(energy_companies.Ticker)]

# %%
energy_prices.reset_index(drop=True, inplace=True)

# %%
energy_prices
# Out:
#        Ticker  SimFinId        Date   Open    Low   High  Close  Adj. Close  \
# 0         APC     67564  2007-01-03  42.37  41.81  43.49  42.23       37.96
# 1         APC     67564  2007-01-04  41.05  40.93  41.98  41.03       36.88
# 2         APC     67564  2007-01-05  40.75  40.53  41.64  41.31       37.14
# 3         APC     67564  2007-01-08  41.90  41.05  42.10  41.35       37.17
# 4         APC     67564  2007-01-09  40.80  40.55  41.89  41.36       37.18
# ...       ...       ...         ...    ...    ...    ...    ...         ...
# 290480    OVV    980326  2019-08-26  21.30  20.85  21.45  21.15       20.03
# 290481    OVV    980326  2019-08-27  21.20  21.05  21.60  21.55       20.41
# 290482    OVV    980326  2019-08-28  21.80  21.45  22.20  21.60       20.46
# 290483    OVV    980326  2019-08-29  21.95  21.60  22.55  22.45       21.27
# 290484    OVV    980326  2019-08-30  22.45  21.85  22.55  22.20       21.03
#
#         Dividend    Volume  Shares Outstanding
# ...

# %%
energy_prices.to_csv('energy_prices.csv')
